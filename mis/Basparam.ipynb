# %%
from itertools import permutations

charachters = ['ا', 'س' , 'پ' , 'ل' , 'ر' , 'م']

for shf_str in permutations(charachters):
    print("".join(shf_str))
# Out:
# اسپلرم
# اسپلمر
# اسپرلم
# اسپرمل
# اسپملر
# اسپمرل
# اسلپرم
# اسلپمر
# اسلرپم
# اسلرمپ
# اسلمپر
# اسلمرپ
# اسرپلم
# اسرپمل
# اسرلپم
# اسرلمپ
# اسرمپل
# اسرملپ
# اسمپلر
# اسمپرل
# اسملپر
# اسملرپ
# اسمرپل
# اسمرلپ
# اپسلرم
# اپسلمر
# اپسرلم
# اپسرمل
# اپسملر
# اپسمرل
# اپلسرم
# اپلسمر
# اپلرسم
# اپلرمس
# اپلمسر
# اپلمرس
# اپرسلم
# اپرسمل
# اپرلسم
# اپرلمس
# اپرمسل
# اپرملس
# اپمسلر
# اپمسرل
# اپملسر
# اپملرس
# اپمرسل
# اپمرلس
# السپرم
# السپمر
# السرپم
# السرمپ
# السمپر
# السمرپ
# الپسرم
# الپسمر
# الپرسم
# الپرمس
# الپمسر
# الپمرس
# الرسپم
# الرسمپ
# الرپسم
# الرپمس
# الرمسپ
# الرمپس
# المسپر
# المسرپ
# المپسر
# المپرس
# المرسپ
# المرپس
# ارسپلم
# ارسپمل
# ارسلپم
# ارسلمپ
# ارسمپل
# ارسملپ
# ارپسلم
# ارپسمل
# ارپلسم
# ارپلمس
# ارپمسل
# ارپملس
# ارلسپم
# ارلسمپ
# ارلپسم
# ارلپمس
# ارلمسپ
# ارلمپس
# ارمسپل
# ارمسلپ
# ارمپسل
# ارمپلس
# ارملسپ
# ارملپس
# امسپلر
# امسپرل
# امسلپر
# امسلرپ
# امسرپل
# امسرلپ
# امپسلر
# امپسرل
# امپلسر
# امپلرس
# امپرسل
# امپرلس
# املسپر
# املسرپ
# املپسر
# ...
